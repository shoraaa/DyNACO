# %%
import papermill as pm
from pathlib import Path

pm.execute_notebook(
    "tsp/train.ipynb",
    "outputs_v4/tsp_out.ipynb",
    cwd="tsp"   # 👈 THIS FIXES IT
)

pm.execute_notebook(
    "cvrp/train.ipynb",
    "outputs_v4/cvrp_out.ipynb",
    cwd="cvrp"   # 👈 THIS FIXES Ihfjnvm T
)
# Out:
# ...
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
