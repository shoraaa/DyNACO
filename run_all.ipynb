# %%
import papermill as pm
from pathlib import Path

PROJECT_ROOT = Path(".").resolve()

pm.execute_notebook(
    "tsp/train.ipynb",
    "outputs/tsp_out.ipynb",
    parameters={"PROJECT_ROOT": str(PROJECT_ROOT)},
)

pm.execute_notebook(
    "cvrp/train.ipynb",
    "outputs/cvrp_out.ipynb",
    parameters={"PROJECT_ROOT": str(PROJECT_ROOT)},
)
