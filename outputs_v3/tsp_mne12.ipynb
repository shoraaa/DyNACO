# %%
import time
import torch
import os
import IPython.display as display

if not hasattr(display, "set_matplotlib_formats"):
    # no-op fallback (or you can force retina/png instead)
    def set_matplotlib_formats(*args, **kwargs):
        return None
    display.set_matplotlib_formats = set_matplotlib_formats

from d2l.torch import Animator

from net import Net
from utils import load_val_dataset
from faco import MFACO_TSP

from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
PRETRAINED_DIR = PROJECT_ROOT / "../pretrained"

# Optional wandb logging (lazy import to avoid hangs at import-time)
USE_WANDB = True
WANDB_PROJECT = os.environ.get("WANDB_PROJECT", "claco")
WANDB_ENTITY = os.environ.get("WANDB_ENTITY") or None
WANDB_MODE = os.environ.get("WANDB_MODE", "online")  # set to "offline" to avoid network
wandb = None

def _wandb_init(config: dict, name: str | None = None):
    """Init a fresh wandb run for each train() call.

    In notebooks it's common to re-run the train cell; reusing the same wandb run
    causes non-monotonic step warnings when we log with an explicit `step=`.
    """
    global wandb, USE_WANDB
    if not USE_WANDB:
        return None
    if wandb is None:
        try:
            import wandb as _wandb
            wandb = _wandb
        except Exception as e:
            USE_WANDB = False
            print("wandb disabled (import failed):", e)
            return None
    if wandb.run is not None:
        # Start a new run to avoid step going backwards on re-runs.
        try:
            wandb.finish()
        except Exception:
            pass
    return wandb.init(
        project=WANDB_PROJECT,
        entity=WANDB_ENTITY,
        config=config,
        name=name,
        mode=WANDB_MODE,
    )

torch.manual_seed(1234)

lr = 1e-4
H=10
mini_H=100
rho = 0.5
min_new_edges = 12
disable_heuristic = False
use_local_search = True
smooth_mmas = True
extend_ls = True
normalize_heuristic = True
no_logit_net = False
no_dynamic_feats = False
k_sparse = 32
n_ants = 100
steps_per_epoch = 32
epochs = 10

device = 'cuda:0'

# Import your compiled extension (needed for get_max_threads print below)
try:
    import faco_tsp
except Exception as e:
    faco_tsp = None
    print("Warning: could not import faco_tsp:", e)

if faco_tsp is not None:
    print("faco_tsp imported. OpenMP max threads:", faco_tsp.get_max_threads())
# Out:
# faco_tsp imported. OpenMP max threads: 10

# %%
# Import training logic from train.py (keep notebook focused on experiments/plots)
from types import SimpleNamespace
import train as train_mod
from tqdm.notebook import tqdm as notebook_tqdm
from functools import partial

# Patch the tqdm symbol used inside train.py
train_mod.tqdm = partial(notebook_tqdm, disable=True)


# Re-export helpers if you still want to inspect/DEBUG them in notebook
_popcount_i64 = train_mod._popcount_i64
replay_logp_from_cpp_batch_trace = train_mod.replay_logp_from_cpp_batch_trace
train_instance = train_mod.train_instance
train_epoch_core = train_mod.train_epoch
validation_core = train_mod.validation


def _make_args(n_node, k_sparse, n_ants, steps_per_epoch, *, H, mini_H, device,
              rho=0.1, min_new_edges=8,
              disable_heuristic=True,
              use_local_search=True,
              smooth_mmas=False,
              extend_ls=False,
              normalized_heuristic=False,
              debug=False,
              use_wandb=False,
              no_logit_net=False,
              baseline='none', baseline_runs=1, baseline_time_limit=10.0):
    """Create a train.py-compatible args namespace from notebook globals."""
    return SimpleNamespace(
        # problem / graph
        n_node=int(n_node),
        k_sparse=int(k_sparse),
        n_ants=int(n_ants),
        steps_per_epoch=int(steps_per_epoch),
        epochs=None,
        lr=lr,
        seed=1234,
        device=str(device),

        # aco
        rho=float(rho),
        min_new_edges=int(min_new_edges),
        H=int(H),
        mini_H=int(mini_H),
        disable_heuristic=bool(disable_heuristic),
        no_local_search=not bool(use_local_search),
        no_smooth_mmas=not bool(smooth_mmas),
        extend_ls=bool(extend_ls),
        no_normalized_heuristic=not bool(normalized_heuristic),
        debug=bool(debug),
        no_logit_net=bool(no_logit_net),

        # logging
        no_wandb=not bool(use_wandb),
        wandb_project=WANDB_PROJECT,
        wandb_entity=WANDB_ENTITY,
        save_dir=str(PRETRAINED_DIR / 'tsp'),
        no_dynamic_feats=False,

        # baseline (validation)
        baseline=str(baseline),
        baseline_runs=int(baseline_runs),
        baseline_time_limit=float(baseline_time_limit),
    )


@torch.no_grad()
def validation(n_ants, epoch, net, val_dataset, k_sparse, animator, dynamic, args, baseline_values=None):
    """Notebook wrapper around train.py validation (keeps the old Animator plotting style)."""
    avg_last, avg_best, _gap = validation_core(
        args=args,
        epoch=epoch,
        net=net,
        val_dataset=val_dataset,
        dynamic=dynamic,
        baseline_values=baseline_values,
    )
    if animator is not None:
        animator.add(epoch + 1, (avg_last, avg_best))
    return avg_last, avg_best


def train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, dynamic,
          *,
          H=H,
          mini_H=mini_H,
          rho=rho,
          min_new_edges=min_new_edges,
          disable_heuristic=disable_heuristic,
          use_local_search=use_local_search,
          smooth_mmas=smooth_mmas,
          extend_ls=extend_ls,
          normalized_heuristic=normalize_heuristic,
          debug=False,
          use_wandb=USE_WANDB,
          no_logit_net=False,
          baseline='none',
          baseline_runs=1,
          baseline_time_limit=10.0,
          baseline_values=None,
          ):

    args = _make_args(
        n_node=n_node,
        k_sparse=k_sparse,
        n_ants=n_ants,
        steps_per_epoch=steps_per_epoch,
        H=H,
        mini_H=mini_H,
        device=device,
        rho=rho,
        min_new_edges=min_new_edges,
        disable_heuristic=disable_heuristic,
        use_local_search=use_local_search,
        smooth_mmas=smooth_mmas,
        extend_ls=extend_ls,
        normalized_heuristic=normalized_heuristic,
        debug=debug,
        use_wandb=use_wandb,
        no_logit_net=no_logit_net,
        baseline=baseline,
        baseline_runs=baseline_runs,
        baseline_time_limit=baseline_time_limit,
    )

    # (Optional) wandb init: keep the notebook helper, but make train.py see the same module
    run = None
    if use_wandb:
        run = _wandb_init(config=vars(args), name=f"tsp{n_node}")
        # make sure train.py logs to the same wandb module
        try:
            import wandb as _wb
            train_mod.wandb = _wb
            args.no_wandb = False
        except Exception as e:
            print('wandb disabled (import failed):', e)
            args.no_wandb = True

    net = Net(logit_net=not no_logit_net).to(device)
    optimizer = torch.optim.AdamW(net.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs, eta_min=lr * 0.1)

    val_list = load_val_dataset(n_node, device)
    animator = Animator(xlabel='epoch', xlim=[0, epochs], legend=["Avg. sample obj.", "Best ACO obj."])

    avg_last, avg_aco_best = validation(n_ants, -1, net, val_list, k_sparse, animator, dynamic, args, baseline_values=baseline_values)
    val_results = [(avg_last, avg_aco_best)]

    global_step = 0
    sum_time = 0
    best_val = float('inf')

    for epoch in range(0, epochs):
        start = time.time()
        global_step, _train_avg_cost = train_epoch_core(args, epoch, net, optimizer, global_step, dynamic=dynamic)
        scheduler.step()
        sum_time += time.time() - start

        avg_last, avg_aco_best = validation(n_ants, epoch, net, val_list, k_sparse, animator, dynamic, args, baseline_values=baseline_values)
        val_results.append((avg_last, avg_aco_best))

        if avg_aco_best < best_val:
            best_val = avg_aco_best
            os.makedirs(PRETRAINED_DIR / 'tsp', exist_ok=True)
            torch.save(net.state_dict(), f"{PRETRAINED_DIR}/tsp/tsp{n_node}.pt")

    print('total training duration:', sum_time)

    for epoch in range(-1, epochs):
        print(f'epoch {epoch}:', val_results[epoch + 1])

    if use_wandb and run is not None:
        try:
            import wandb as _wb
            _wb.finish()
        except Exception:
            pass

    # return net, val_results

# %% [markdown]
# Learn heuristic for TSP100:

# %%
n_node = 100
n_ants = 100
k_sparse = 32
steps_per_epoch = 32
epochs = 10

train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)
# Out:
# total training duration: 1050.1563839912415
# epoch -1: (8.280053175985813, 7.819921690970659)
# epoch 0: (8.241547398269176, 7.8204533234238625)
# epoch 1: (8.046262510120869, 7.821976915001869)
# epoch 2: (7.855773389339447, 7.823318935930729)
# epoch 3: (7.826945286244154, 7.823739465326071)
# epoch 4: (7.826104395091534, 7.825425885617733)
# epoch 5: (7.825729373842478, 7.825340088456869)
# epoch 6: (7.823364682495594, 7.823205891996622)
# epoch 7: (7.824389684945345, 7.824053198099136)
# epoch 8: (7.8250144720077515, 7.82474772632122)
# epoch 9: (7.824633061885834, 7.82423485070467)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>█▇▆▅▆▇▆▅▃▄▇▅▄▅▂▂▅▆▇▆▆▅▃▃▂▁▄▂▃▆▂▅▇█▄▆▆▄▃▅</td></tr><tr><td>train/best_cost</td><td>▅▂▄▇▄▂▄▃▅▃▄▁▃█▂▄▅▅▅▅▇▄▆▅▅▅█▂▅▅▃▅▂▆▄▅▆▃▅▄</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>7.75608</td></tr><tr><td>train/best_cost</td><td>7.75608</td></tr><tr><td>train/epoch</td><td>9</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">tsp100</strong> at: <a href='https://wandb.ai/shoraaa-vnu/claco/runs/mdwwv9mf' target="_blank">https://wandb.ai/shoraaa-vnu/claco/runs/mdwwv9mf</a><br> View project at: <a href='https://wandb.ai/shoraaa-vnu/claco' target="_blank">https://wandb.ai/shoraaa-vnu/claco</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260119_001915-mdwwv9mf/logs</code>

# %% [markdown]
# Learn heuristic for TSP500:

# %%
# n_node = 200
# n_ants = 100
# k_sparse = 32
# steps_per_epoch = 32
# epochs = 10
# train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)

# %%
n_node = 500
n_ants = 100
k_sparse = 32
steps_per_epoch = 32
epochs = 10
train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)
# Out:
# total training duration: 1115.1710267066956
# epoch -1: (17.079782396554947, 16.658998146653175)
# epoch 0: (17.068726882338524, 16.670364767313004)
# epoch 1: (17.02726359665394, 16.67593352496624)
# epoch 2: (16.95165166258812, 16.66260389983654)
# epoch 3: (16.879093781113625, 16.6611295491457)
# epoch 4: (16.848227098584175, 16.663819029927254)
# epoch 5: (16.82729758322239, 16.664754435420036)
# epoch 6: (16.814940631389618, 16.65780843794346)
# epoch 7: (16.796849876642227, 16.651715248823166)
# epoch 8: (16.789978608489037, 16.653476640582085)
# epoch 9: (16.7788787484169, 16.652831986546516)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>▅▆▅▅▃███▃▅▅▄▄▄▃▂▆▆▅▃▃▅▃▄▆▃▂▁▃▁▂▁▂▅▄▄▅▂▆▃</td></tr><tr><td>train/best_cost</td><td>▆▄▁▃▁▆▁▇▅▂▄▄▃▆█▃█▇▆▂▁▆▅▂▅▅▆▄▅▆▃▆▅▂▅▂▃▄▆▆</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>16.68134</td></tr><tr><td>train/best_cost</td><td>16.54418</td></tr><tr><td>train/epoch</td><td>9</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">tsp500</strong> at: <a href='https://wandb.ai/shoraaa-vnu/claco/runs/ffpng1wu' target="_blank">https://wandb.ai/shoraaa-vnu/claco/runs/ffpng1wu</a><br> View project at: <a href='https://wandb.ai/shoraaa-vnu/claco' target="_blank">https://wandb.ai/shoraaa-vnu/claco</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260119_005201-ffpng1wu/logs</code>

# %%
n_node = 1000
n_ants = 100
k_sparse = 32
steps_per_epoch = 32
epochs = 10
train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)
# Out:
# total training duration: 1254.9759602546692
# epoch -1: (23.806955337524414, 23.459272980690002)
# epoch 0: (23.80498433113098, 23.491442680358887)
# epoch 1: (23.744317412376404, 23.48243248462677)
# epoch 2: (23.67754054069519, 23.45067024230957)
# epoch 3: (23.590754866600037, 23.411858677864075)
# epoch 4: (23.526296257972717, 23.375836610794067)
# epoch 5: (23.474249958992004, 23.361908793449402)
# epoch 6: (23.454225897789, 23.359729290008545)
# epoch 7: (23.422799348831177, 23.34280800819397)
# epoch 8: (23.431024312973022, 23.35036039352417)
# epoch 9: (23.428990483283997, 23.352136611938477)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>▂▅█▇▇▆▅▂▆▆▆▄▆▅▆▅▃▄▆▄▂▂▄▂▄▁▃▂▅▂▃▃▆▄▂▄▃▄▃▆</td></tr><tr><td>train/best_cost</td><td>▄▃▆▅▅▅▆▆▄▃▄▅▃█▄▄▅▄█▃▃▅▄▄▆▂▃▅▂▄▇▄▆▅▇▆▅▁▄▃</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/avg_cost</td><td>23.50458</td></tr><tr><td>train/best_cost</td><td>23.43327</td></tr><tr><td>train/epoch</td><td>9</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">tsp1000</strong> at: <a href='https://wandb.ai/shoraaa-vnu/claco/runs/wehwvjwn' target="_blank">https://wandb.ai/shoraaa-vnu/claco/runs/wehwvjwn</a><br> View project at: <a href='https://wandb.ai/shoraaa-vnu/claco' target="_blank">https://wandb.ai/shoraaa-vnu/claco</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260119_012825-wehwvjwn/logs</code>

# %%
# n_nod  , k_sparse, n_ants, steps_per_epoch, epochs, True)

# %%
n_node = 5000
n_ants = 100
k_sparse = 32
steps_per_epoch = 32
epochs = 10
train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 6
#       4 steps_per_epoch = 32
#       5 epochs = 10
# ----> 6 train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, True)
#
# Cell In[10], line 157, in train(n_node, k_sparse, n_ants, steps_per_epoch, epochs, dynamic, H, mini_H, rho, min_new_edges, disable_heuristic, use_local_search, smooth_mmas, extend_ls, normalized_heuristic, debug, use_wandb, no_logit_net, baseline, baseline_runs, baseline_time_limit, baseline_values)
#     155 for epoch in range(0, epochs):
#     156     start = time.time()
# --> 157     global_step, _train_avg_cost = train_epoch_core(args, epoch, net, optimizer, global_step, dynamic=dynamic)
#     158     scheduler.step()
#     159     sum_time += time.time() - start
#
# File ~/Research/old/NGFACO/tsp/train.py:205, in train_epoch(args, epoch, net, optimizer, global_step, dynamic)
#     199     # 4. Center diversity (diversity advantage)
#     200     # We want high diversity.
#     201     # "Center across ant (same way as cost do)" -> (val - mean)
#     202     div_adv = (diversity - diversity.mean()).detach()
#     204     # 5. Combine with cost advantage
# --> 205     # Original: loss = (adv_cost * logp).mean()
#     206     # adv_cost = (cost - mean_cost) (we minimize this)
#     207     #
#     208     # If we want to encourage diversity, we want to MINIMIZE -Diversity (or Maximize Diversity).
#     209     # Equivalently, if diversity is high, div_adv > 0.
#     210     # We want to encourage actions that led to high diversity.
#     211     # So we should give them POSITIVE REWARD (negative loss).
#     212     #
#     213     # If we add to ADVANTAGE:
#     214     # Total Adv = Scaled Cost Adv + Scaled Diversity Adv
#     215     # Cost Adv: (Cost - Mean). Lower is better. Minimizing (Cost - Mean) * logp pushes probs up for low cost.
#     216     # Diversity Adv: We want High Diversity.
#     217     # If we use term `- lambda * (Diversity - Mean)`:
#     218     # High diversity -> term is negative.
#     219     # Minimizing `negative * logp` -> maximizes logp. Correct.
#     220     #
#     221     # So effective advantage = (Cost - Mean) - lambda * (Diversity - Mean)
#     223     adv = adv - args.diversity_loss * div_adv
#     225 loss = (adv * logp_per_ant).mean()
#
# File ~/Research/old/NGFACO/tsp/train.py:155, in train_instance(model, optimizer, coords, k_sparse, n_ants, dynamic, args)
#     152 losses = 0
#     153 for mini_t in range(args.mini_H):
#     154     # 1) sample + trace from C++
# --> 155     costs, flats, _, logps_cpp, traces, costs_raw, flats_raw = aco.sample(require_prob=True, prior=heu_mat)
#     156     costs_t = torch.as_tensor(costs, device=args.device, dtype=torch.float32)
#     158     # 2) differentiable prob table for training
#
# File ~/Research/old/NGFACO/tsp/faco.py:397, in MFACO_TSP.sample(self, invtemp, require_prob, prior, parallel_traced)
#     392         raise ValueError(
#     393             f"prior must be shape (n, k)=({n}, {k}) for C++ backend; got {arr.shape}"
#     394         )
#     395     prior = arr
# --> 397 costs, flats, touched, logps, traces_raw, costs_raw, flats_raw = self._cpp.sample(
#     398     invtemp, require_prob, prior, parallel_traced
#     399 )
#     401 # Keep the C++ batch trace object (much faster than converting to Python lists)
#     402 traces = traces_raw
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7fddb4444af0>> (for post_run_cell), with arguments args (<ExecutionResult object at 7fddcc020910, execution_count=16 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 7fddcc0239d0, raw_cell="n_node = 5000
# n_ants = 100
# k_sparse = 32
# steps_per.." transformed_cell="n_node = 5000
# n_ants = 100
# k_sparse = 32
# steps_per.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/shora/Research/old/NGFACO/tsp/train.ipynb#X12sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/wandb_init.py:604, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     601     return
#     603 self._logger.info("resuming backend")
# --> 604 self.backend.interface.publish_resume()
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/Research/old/NGFACO/.venv/lib/python3.13/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/asyncio/streams.py:386, in StreamWriter.drain(self)
#     375 if self._transport.is_closing():
#     376     # Wait for protocol.connection_lost() call
#     377     # Raise connection closing error if any,
#    (...)    383     # in a loop would never call connection_lost(), so it
#     384     # would not see an error when the socket is closed.
#     385     await sleep(0)
# --> 386 await self._protocol._drain_helper()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost
